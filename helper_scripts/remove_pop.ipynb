# %%
import pandas as pd

# %%
tracks = pd.read_csv('tracks.csv')
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106574 entries, 0 to 106573
# Data columns (total 53 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   track_id           106574 non-null  int64
#  1   comments           106574 non-null  int64
#  2   date_created       103045 non-null  object
#  3   date_released      70294 non-null   object
#  4   engineer           15295 non-null   object
#  5   favorites          106574 non-null  int64
#  6   id                 106574 non-null  int64
#  7   information        83149 non-null   object
#  8   listens            106574 non-null  int64
#  9   producer           18060 non-null   object
#  10  tags               106574 non-null  object
#  11  title              105549 non-null  object
#  12  tracks             106574 non-null  int64
#  13  type               100066 non-null  object
#  14  active_year_begin  22711 non-null   object
# ...

# %%
tracks[tracks['track_id'] == 27547]['genre_top']
# Out:
# 17052    Pop
# Name: genre_top, dtype: object

# %%
for name in ["train_meta.csv", "val_meta.csv"]:
    df = pd.read_csv(name)

    df = df[df["genre"] != 6]

    print(name)
    print(df["genre"].value_counts())

    df.to_csv(f'{name.split('.')[0]}_nopop.csv', index=False)
# Out:
# train_meta.csv
# genre
# 7    821
# 4    807
# 0    806
# 1    803
# 3    794
# 2    793
# 5    786
# Name: count, dtype: int64
# val_meta.csv
# genre
# 5    214
# 2    207
# 3    206
# 1    196
# 4    193
# 0    193
# 7    178
# Name: count, dtype: int64
